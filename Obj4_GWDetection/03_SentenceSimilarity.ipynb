# %% [markdown]
# # 03_Sentence Similarity

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util

# %% [markdown]
# ### Define File Paths

# %%
fname_sdg           = '../Data/Output/sdg.xlsx'
fname_sentences     = '../Data/Output/CorpRepSentences.csv'
fname_similarity    = '../Data/Output/ResultSimilarity.csv'

# %% [markdown]
# ### Read SDG File & Clean Data

# %%
df_sdg = pd.read_excel(fname_sdg)

# %%
# Replace characters that are not on the keyboard with a space.
reg_str = r'[^!"#$%&\'()*+,-./:;<=>?@\[\]^_\`{|}~\\\\0-9a-zA-Z]'
df_sdg['sentence'] = df_sdg['sentence'].str.replace(reg_str,' ', regex=True)

# %%
df_sdg
# Out:
#     gpnum        gpname goalnum  \
# 0    gp01          Life  goal01
# 1    gp01          Life  goal01
# 2    gp01          Life  goal01
# 3    gp01          Life  goal01
# 4    gp01          Life  goal01
# ..    ...           ...     ...
# 636  gp06  Environments  goal15
# 637  gp06  Environments  goal15
# 638  gp06  Environments  goal15
# 639  gp06  Environments  goal15
# 640  gp06  Environments  goal15
#
#                                               sentence
# 0              End poverty in all its forms everywhere
# 1    Despite progress under the MDGs, approximately...
# 2    Over the past decade, markets in developing co...
# 3    Certain groups are disproportionately represen...
# 4    These include women, persons with disabilities...
# ..                                                 ...
# 636  15.7 Take urgent action to end poaching and tr...
# 637  15.8 By 2020, introduce measures to prevent th...
# 638  15.9 By 2020, integrate ecosystems and biodive...
# 639  15.a Mobilize and significantly increase from ...
# 640  15.c Enhance global support to efforts to comb...
#
# [641 rows x 4 columns]

# %% [markdown]
# ### Read Report Sentences & Clean Data

# %%
df_report = pd.read_csv(fname_sentences)

# %%
# Replace characters that are not on the keyboard with a space.
reg_str = r'[^!"#$%&\'()*+,-./:;<=>?@\[\]^_\`{|}~\\\\0-9a-zA-Z]'
df_report['sentence'] = df_report['sentence'].str.replace(reg_str,' ', regex=True)

# %%
df_report
# Out:
#         doc_id            fname  \
# 0            1    Asda_2020.pdf
# 1            1    Asda_2020.pdf
# 2            1    Asda_2020.pdf
# 3            1    Asda_2020.pdf
# 4            1    Asda_2020.pdf
# ...        ...              ...
# 168272      84  Toyota_2023.pdf
# 168273      84  Toyota_2023.pdf
# 168274      84  Toyota_2023.pdf
# 168275      84  Toyota_2023.pdf
# 168276      84  Toyota_2023.pdf
#
#                                                  sentence
# 0       Our action on sustainability supports the broa...
# 1       In particular, our efforts are contributing to...
# 2       For example, our work to tackle food poverty i...
# 3       Our CCFB strategy covers every aspect of our b...
# 4       It also covers International Procurement and L...
# ...                                                   ...
# 168272  Environmental Data [O] Remanufactured and Used...
# 168273  306-2 Management of significant waste-related ...
# 168274  407-1 Operations and suppliers in which the ri...
# 168275  416-1 Assessment of the health and safety impa...
# 168276  Published: February 2024 Next scheduled report...
#
# [168277 rows x 3 columns]

# %% [markdown]
# ### Calculate Sentence Similarity Scores

# %%
# %%time

# Tokenise sentences
model = SentenceTransformer('all-MiniLM-L6-v2')

# Create lists of sentences
sentences1 = df_sdg['sentence'].tolist()
sentences2 = df_report['sentence'].tolist()

#Compute embeddings for both lists
embedding1 = model.encode(sentences1, convert_to_tensor=True)
embedding2 = model.encode(sentences2, convert_to_tensor=True)

#Compute cosine-similarity
cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
# Out:
# CPU times: user 14min 16s, sys: 17.8 s, total: 14min 34s
# Wall time: 16min 14s

# %%
cosine_scores
# Out:
# tensor([[0.3225, 0.3395, 0.3843,  ..., 0.0955, 0.0643, 0.1310],
#         [0.1070, 0.2133, 0.2176,  ..., 0.0906, 0.0382, 0.0502],
#         [0.3374, 0.3510, 0.2929,  ..., 0.1191, 0.0249, 0.0884],
#         ...,
#         [0.4042, 0.4519, 0.4156,  ..., 0.2157, 0.1781, 0.3476],
#         [0.4758, 0.4257, 0.3900,  ..., 0.2258, 0.2201, 0.2563],
#         [0.3984, 0.3435, 0.3967,  ..., 0.3061, 0.2030, 0.2432]],
#        device='mps:0')

# %%
sim_array = np.array(cosine_scores.cpu()).transpose()

# %%
sim_array.shape
# Out:
# (168277, 641)

# %% [markdown]
# ### Similarity Score for Each Sentence

# %%
sr_sdg = df_sdg['goalnum'].value_counts().sort_index()
sr_sdg
# Out:
# goalnum
# goal01    40
# goal02    38
# goal03    43
# goal04    37
# goal05    43
# goal06    45
# goal07    29
# goal08    42
# goal09    29
# goal10    44
# goal11    35
# goal12    41
# goal13    30
# goal14    40
# goal15    44
# goal16    40
# goal17    21
# Name: count, dtype: int64

# %%
# %%time

sr_sdg = df_sdg['goalnum'].value_counts().sort_index()

# Initialize
for key in sr_sdg.index:
    df_report[key] = 0.0

for idx in df_report.index:
    off_b = 0
    off_e = 0
    
    for key in sr_sdg.index:
        off_b = off_e
        off_e += sr_sdg[key]
        df_report.loc[idx,key] = sim_array[idx][off_b:off_e].mean()
        
    if idx % 1000 == 0:
        print('<cnt:{}, idx:{}> ======================'.format(idx//1000,idx))
        
print('==== End of job ======================')
# Out:
# <cnt:0, idx:0> ======================
# <cnt:1, idx:1000> ======================
# <cnt:2, idx:2000> ======================
# <cnt:3, idx:3000> ======================
# <cnt:4, idx:4000> ======================
# <cnt:5, idx:5000> ======================
# <cnt:6, idx:6000> ======================
# <cnt:7, idx:7000> ======================
# <cnt:8, idx:8000> ======================
# <cnt:9, idx:9000> ======================
# <cnt:10, idx:10000> ======================
# <cnt:11, idx:11000> ======================
# <cnt:12, idx:12000> ======================
# <cnt:13, idx:13000> ======================
# <cnt:14, idx:14000> ======================
# <cnt:15, idx:15000> ======================
# <cnt:16, idx:16000> ======================
# <cnt:17, idx:17000> ======================
# <cnt:18, idx:18000> ======================
# <cnt:19, idx:19000> ======================
# <cnt:20, idx:20000> ======================
# <cnt:21, idx:21000> ======================
# <cnt:22, idx:22000> ======================
# <cnt:23, idx:23000> ======================
# <cnt:24, idx:24000> ======================
# <cnt:25, idx:25000> ======================
# <cnt:26, idx:26000> ======================
# <cnt:27, idx:27000> ======================
# <cnt:28, idx:28000> ======================
# <cnt:29, idx:29000> ======================
# <cnt:30, idx:30000> ======================
# <cnt:31, idx:31000> ======================
# <cnt:32, idx:32000> ======================
# <cnt:33, idx:33000> ======================
# <cnt:34, idx:34000> ======================
# <cnt:35, idx:35000> ======================
# <cnt:36, idx:36000> ======================
# <cnt:37, idx:37000> ======================
# <cnt:38, idx:38000> ======================
# <cnt:39, idx:39000> ======================
# <cnt:40, idx:40000> ======================
# <cnt:41, idx:41000> ======================
# <cnt:42, idx:42000> ======================
# <cnt:43, idx:43000> ======================
# <cnt:44, idx:44000> ======================
# <cnt:45, idx:45000> ======================
# <cnt:46, idx:46000> ======================
# <cnt:47, idx:47000> ======================
# <cnt:48, idx:48000> ======================
# <cnt:49, idx:49000> ======================
# <cnt:50, idx:50000> ======================
# <cnt:51, idx:51000> ======================
# <cnt:52, idx:52000> ======================
# <cnt:53, idx:53000> ======================
# <cnt:54, idx:54000> ======================
# <cnt:55, idx:55000> ======================
# <cnt:56, idx:56000> ======================
# <cnt:57, idx:57000> ======================
# <cnt:58, idx:58000> ======================
# <cnt:59, idx:59000> ======================
# <cnt:60, idx:60000> ======================
# <cnt:61, idx:61000> ======================
# <cnt:62, idx:62000> ======================
# <cnt:63, idx:63000> ======================
# <cnt:64, idx:64000> ======================
# <cnt:65, idx:65000> ======================
# <cnt:66, idx:66000> ======================
# <cnt:67, idx:67000> ======================
# <cnt:68, idx:68000> ======================
# <cnt:69, idx:69000> ======================
# <cnt:70, idx:70000> ======================
# <cnt:71, idx:71000> ======================
# <cnt:72, idx:72000> ======================
# <cnt:73, idx:73000> ======================
# <cnt:74, idx:74000> ======================
# <cnt:75, idx:75000> ======================
# <cnt:76, idx:76000> ======================
# <cnt:77, idx:77000> ======================
# <cnt:78, idx:78000> ======================
# <cnt:79, idx:79000> ======================
# <cnt:80, idx:80000> ======================
# <cnt:81, idx:81000> ======================
# <cnt:82, idx:82000> ======================
# <cnt:83, idx:83000> ======================
# <cnt:84, idx:84000> ======================
# <cnt:85, idx:85000> ======================
# <cnt:86, idx:86000> ======================
# <cnt:87, idx:87000> ======================
# <cnt:88, idx:88000> ======================
# <cnt:89, idx:89000> ======================
# <cnt:90, idx:90000> ======================
# <cnt:91, idx:91000> ======================
# <cnt:92, idx:92000> ======================
# <cnt:93, idx:93000> ======================
# <cnt:94, idx:94000> ======================
# <cnt:95, idx:95000> ======================
# <cnt:96, idx:96000> ======================
# <cnt:97, idx:97000> ======================
# <cnt:98, idx:98000> ======================
# <cnt:99, idx:99000> ======================
# <cnt:100, idx:100000> ======================
# <cnt:101, idx:101000> ======================
# <cnt:102, idx:102000> ======================
# <cnt:103, idx:103000> ======================
# <cnt:104, idx:104000> ======================
# <cnt:105, idx:105000> ======================
# <cnt:106, idx:106000> ======================
# <cnt:107, idx:107000> ======================
# <cnt:108, idx:108000> ======================
# <cnt:109, idx:109000> ======================
# <cnt:110, idx:110000> ======================
# <cnt:111, idx:111000> ======================
# <cnt:112, idx:112000> ======================
# <cnt:113, idx:113000> ======================
# <cnt:114, idx:114000> ======================
# <cnt:115, idx:115000> ======================
# <cnt:116, idx:116000> ======================
# <cnt:117, idx:117000> ======================
# <cnt:118, idx:118000> ======================
# <cnt:119, idx:119000> ======================
# <cnt:120, idx:120000> ======================
# <cnt:121, idx:121000> ======================
# <cnt:122, idx:122000> ======================
# <cnt:123, idx:123000> ======================
# <cnt:124, idx:124000> ======================
# <cnt:125, idx:125000> ======================
# <cnt:126, idx:126000> ======================
# <cnt:127, idx:127000> ======================
# <cnt:128, idx:128000> ======================
# <cnt:129, idx:129000> ======================
# <cnt:130, idx:130000> ======================
# <cnt:131, idx:131000> ======================
# <cnt:132, idx:132000> ======================
# <cnt:133, idx:133000> ======================
# <cnt:134, idx:134000> ======================
# <cnt:135, idx:135000> ======================
# <cnt:136, idx:136000> ======================
# <cnt:137, idx:137000> ======================
# <cnt:138, idx:138000> ======================
# <cnt:139, idx:139000> ======================
# <cnt:140, idx:140000> ======================
# <cnt:141, idx:141000> ======================
# <cnt:142, idx:142000> ======================
# <cnt:143, idx:143000> ======================
# <cnt:144, idx:144000> ======================
# <cnt:145, idx:145000> ======================
# <cnt:146, idx:146000> ======================
# <cnt:147, idx:147000> ======================
# <cnt:148, idx:148000> ======================
# <cnt:149, idx:149000> ======================
# <cnt:150, idx:150000> ======================
# <cnt:151, idx:151000> ======================
# <cnt:152, idx:152000> ======================
# <cnt:153, idx:153000> ======================
# <cnt:154, idx:154000> ======================
# <cnt:155, idx:155000> ======================
# <cnt:156, idx:156000> ======================
# <cnt:157, idx:157000> ======================
# <cnt:158, idx:158000> ======================
# <cnt:159, idx:159000> ======================
# <cnt:160, idx:160000> ======================
# <cnt:161, idx:161000> ======================
# <cnt:162, idx:162000> ======================
# <cnt:163, idx:163000> ======================
# <cnt:164, idx:164000> ======================
# <cnt:165, idx:165000> ======================
# <cnt:166, idx:166000> ======================
# <cnt:167, idx:167000> ======================
# <cnt:168, idx:168000> ======================
# ==== End of job ======================
# CPU times: user 2min 39s, sys: 377 ms, total: 2min 39s
# Wall time: 2min 40s

# %%
df_report
# Out:
#         doc_id            fname  \
# 0            1    Asda_2020.pdf
# 1            1    Asda_2020.pdf
# 2            1    Asda_2020.pdf
# 3            1    Asda_2020.pdf
# 4            1    Asda_2020.pdf
# ...        ...              ...
# 168272      84  Toyota_2023.pdf
# 168273      84  Toyota_2023.pdf
# 168274      84  Toyota_2023.pdf
# 168275      84  Toyota_2023.pdf
# 168276      84  Toyota_2023.pdf
#
#                                                  sentence    goal01    goal02  \
# 0       Our action on sustainability supports the broa...  0.220957  0.249609
# 1       In particular, our efforts are contributing to...  0.247329  0.282171
# 2       For example, our work to tackle food poverty i...  0.239850  0.288944
# 3       Our CCFB strategy covers every aspect of our b...  0.157094  0.224665
# 4       It also covers International Procurement and L...  0.163866  0.202955
# ...                                                   ...       ...       ...
# 168272  Environmental Data [O] Remanufactured and Used...  0.113916  0.153440
# 168273  306-2 Management of significant waste-related ...  0.155386  0.216601
# 168274  407-1 Operations and suppliers in which the ri...  0.241352  0.238156
# 168275  416-1 Assessment of the health and safety impa...  0.180509  0.204682
# 168276  Published: February 2024 Next scheduled report...  0.131855  0.181635
#
#           goal03    goal04    goal05    goal06    goal07    goal08    goal09  \
# 0       0.209004  0.140543  0.302925  0.211519  0.161349  0.215691  0.296752
# 1       0.244253  0.187107  0.321928  0.249514  0.175626  0.230185  0.322435
# 2       0.202165  0.158243  0.244996  0.173143  0.131375  0.201546  0.242778
# 3       0.140007  0.108842  0.212423  0.155067  0.143242  0.163626  0.156430
# 4       0.155638  0.131375  0.238785  0.139401  0.129099  0.191975  0.146139
# ...          ...       ...       ...       ...       ...       ...       ...
# 168272  0.114095  0.094321  0.159580  0.110153  0.082341  0.105566  0.225363
# 168273  0.160928  0.133781  0.191180  0.150989  0.134371  0.154997  0.261323
# 168274  0.235872  0.244054  0.231353  0.268405  0.244760  0.254164  0.226894
# 168275  0.216033  0.113025  0.187275  0.158147  0.194934  0.184066  0.246529
# 168276  0.223244  0.119349  0.165879  0.190081  0.141672  0.124123  0.220616
#
#           goal10    goal11    goal12    goal13    goal14    goal15    goal16  \
# 0       0.221673  0.320755  0.243053  0.316457  0.310363  0.266566  0.314579
# 1       0.231982  0.318060  0.236173  0.324246  0.298038  0.283017  0.303132
# 2       0.165640  0.270407  0.211620  0.294024  0.282431  0.283044  0.311684
# 3       0.154378  0.153755  0.101164  0.180990  0.223748  0.151392  0.173541
# 4       0.171683  0.183722  0.090505  0.175276  0.187808  0.142089  0.164518
# ...          ...       ...       ...       ...       ...       ...       ...
# 168272  0.113817  0.245668  0.303303  0.320671  0.328372  0.292591  0.263292
# 168273  0.182886  0.265438  0.285949  0.295571  0.356245  0.336346  0.338445
# 168274  0.233353  0.233371  0.185475  0.189659  0.195256  0.186064  0.204810
# 168275  0.253336  0.205350  0.134587  0.155782  0.211357  0.174801  0.196577
# 168276  0.199024  0.188044  0.167618  0.180504  0.176390  0.189743  0.172848
#
#           goal17
# 0       0.301656
# 1       0.284681
# 2       0.272534
# 3       0.154607
# 4       0.144709
# ...          ...
# 168272  0.249364
# 168273  0.354660
# 168274  0.209217
# 168275  0.181328
# 168276  0.258593
#
# [168277 rows x 20 columns]

# %% [markdown]
# ### Saving the Result

# %%
# Let's save the result into csv format

df_report.to_csv(fname_similarity, index=False)

# %%
# Let's save the result into pickle format (a binary format for serialising Python objects):
fname_similarity_pkl    = '../Data/Output/ResultSimilarity.pkl'
df_report.to_pickle(fname_similarity_pkl)

# %% [markdown]
# ---

# %%
# End of file
