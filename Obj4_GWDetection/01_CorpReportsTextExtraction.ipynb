# %% [markdown]
# # 1. Text Extraction from Corporate reports (PDFs)

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import os
import fitz # PyMuPDF
import nltk
from nltk.tokenize import sent_tokenize
# Ensure NLTK 'punkt' resource is downloaded
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/luca/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Define File Paths

# %%
path_pdf  = '../Data/Input/Reports'
fname_out = '../Data/Output/CorpRepSentences.csv'

# %% [markdown]
# ### Define Function: Get count of words (only alphabets)

# %%
def get_cnt(text):
    cnt = 0
    for word in text.split():
        if word.isalpha():
            cnt += 1
    return cnt

# %% [markdown]
# ### Define Function: Get text from blocks

# %%
def get_Mytext(block_lst):

    MIN_WORD_CNT = 10 
    
    text_lst = []
    for block in block_lst:
        if block[6] != 0: continue # block_type: 0 = text
    
        text = block[4]
        text = text.replace('fi ', 'fi') # PyMuPDF(fitz) bug fix: 'fi ' --> 'fi'
    
        if get_cnt(text) < MIN_WORD_CNT: continue # Delete sentences with less than MIN_WORD_CNT(10) 
    
        text_lst.append(text.replace('-\n', '')) # To ensures that any hyphenated words split across lines are joined properly in the resulting text.
        
    return ('\n'.join(text_lst))

# %% [markdown]
# ### Define Function: Get sentences from PDF files

# %%
def get_sentence(fname, skip_page = (0,)):
 
    doc = fitz.open(fname)
    
    sent_lst = []
    for page_no, page in enumerate(doc):

        # Skip page
        if page_no+1 in skip_page: continue
        
        block_lst = page.get_text('blocks') #####
        text = get_Mytext(block_lst)
    
        for i, sentence in enumerate(sent_tokenize(text)):
            r_sent = ' '.join(sentence.split()) # Delete '\n', '\t' and strip
            sent_lst.append(r_sent)
            
    doc.close()

    return sent_lst

# %% [markdown]
# ### Define Function: Generate document (DataFrame)

# %%
def gen_document(doc_id, fname, sent_lst):

    res_df = pd.DataFrame(
        {
            'doc_id': doc_id,
            'fname': fname,
            'sentence': sent_lst
        }
    )
    
    return res_df

# %% [markdown]
# ### Define Function: Read PDF file list

# %%
def read_filelist(path):

    # Create empty DataFrame
    df = pd.DataFrame()
    
    # Read and sort the file list (directory)
    file_list = sorted(os.listdir(path))

    # Iterate through the sorted file list
    for idx, fname in enumerate(file_list):
    # Read file list (directory)
    # for idx, fname in enumerate(os.listdir(path)):
        p_fname = os.path.join(path, fname)
        print('path + fname >>>', p_fname)
        
        if p_fname.split('.')[-1] != 'pdf': continue # Check for 'pdf' extension
        print('fname >>>',fname)
    
        doc_id = int(idx)
        
        print(f'doc_id = [{doc_id}], fname = [{fname}]')
        print('')
    
        sent_lst = get_sentence(p_fname)
        df_doc   = gen_document(doc_id, fname, sent_lst)
        
        df = pd.concat([df,df_doc])
        
    return df

# %% [markdown]
# ### Create DataFrame from PDF Files

# %%
# %%time
df = read_filelist(path_pdf)
print('==== End of jobs ====')
# Out:
# path + fname >>> ../Data/Input/Reports/.DS_Store
# path + fname >>> ../Data/Input/Reports/Asda_2020.pdf
# fname >>> Asda_2020.pdf
# doc_id = [1], fname = [Asda_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Asda_2021.pdf
# fname >>> Asda_2021.pdf
# doc_id = [2], fname = [Asda_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Asda_2022.pdf
# fname >>> Asda_2022.pdf
# doc_id = [3], fname = [Asda_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Asda_2023.pdf
# fname >>> Asda_2023.pdf
# doc_id = [4], fname = [Asda_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2014.pdf
# fname >>> Ford_2014.pdf
# doc_id = [5], fname = [Ford_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2015.pdf
# fname >>> Ford_2015.pdf
# doc_id = [6], fname = [Ford_2015.pdf]
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for RichMedia annotations
#
# path + fname >>> ../Data/Input/Reports/Ford_2016.pdf
# fname >>> Ford_2016.pdf
# doc_id = [7], fname = [Ford_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2017.pdf
# fname >>> Ford_2017.pdf
# doc_id = [8], fname = [Ford_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2018.pdf
# fname >>> Ford_2018.pdf
# doc_id = [9], fname = [Ford_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2019.pdf
# fname >>> Ford_2019.pdf
# doc_id = [10], fname = [Ford_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2020.pdf
# fname >>> Ford_2020.pdf
# doc_id = [11], fname = [Ford_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2021.pdf
# fname >>> Ford_2021.pdf
# doc_id = [12], fname = [Ford_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2022.pdf
# fname >>> Ford_2022.pdf
# doc_id = [13], fname = [Ford_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ford_2023.pdf
# fname >>> Ford_2023.pdf
# doc_id = [14], fname = [Ford_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2014.pdf
# fname >>> M&S_2014.pdf
# doc_id = [15], fname = [M&S_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2015.pdf
# fname >>> M&S_2015.pdf
# doc_id = [16], fname = [M&S_2015.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2016.pdf
# fname >>> M&S_2016.pdf
# doc_id = [17], fname = [M&S_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2017.pdf
# fname >>> M&S_2017.pdf
# doc_id = [18], fname = [M&S_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2018.pdf
# fname >>> M&S_2018.pdf
# doc_id = [19], fname = [M&S_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2019.pdf
# fname >>> M&S_2019.pdf
# doc_id = [20], fname = [M&S_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2020.pdf
# fname >>> M&S_2020.pdf
# doc_id = [21], fname = [M&S_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2021.pdf
# fname >>> M&S_2021.pdf
# doc_id = [22], fname = [M&S_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2022.pdf
# fname >>> M&S_2022.pdf
# doc_id = [23], fname = [M&S_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/M&S_2023.pdf
# fname >>> M&S_2023.pdf
# doc_id = [24], fname = [M&S_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2014.pdf
# fname >>> Ocado_2014.pdf
# doc_id = [25], fname = [Ocado_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2015.pdf
# fname >>> Ocado_2015.pdf
# doc_id = [26], fname = [Ocado_2015.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2016.pdf
# fname >>> Ocado_2016.pdf
# doc_id = [27], fname = [Ocado_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2017.pdf
# fname >>> Ocado_2017.pdf
# doc_id = [28], fname = [Ocado_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2018.pdf
# fname >>> Ocado_2018.pdf
# doc_id = [29], fname = [Ocado_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2019.pdf
# fname >>> Ocado_2019.pdf
# doc_id = [30], fname = [Ocado_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2020.pdf
# fname >>> Ocado_2020.pdf
# doc_id = [31], fname = [Ocado_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2021.pdf
# fname >>> Ocado_2021.pdf
# doc_id = [32], fname = [Ocado_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2022.pdf
# fname >>> Ocado_2022.pdf
# doc_id = [33], fname = [Ocado_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Ocado_2023.pdf
# fname >>> Ocado_2023.pdf
# doc_id = [34], fname = [Ocado_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Polestar_2020.pdf
# fname >>> Polestar_2020.pdf
# doc_id = [35], fname = [Polestar_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Polestar_2021.pdf
# fname >>> Polestar_2021.pdf
# doc_id = [36], fname = [Polestar_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Polestar_2022.pdf
# fname >>> Polestar_2022.pdf
# doc_id = [37], fname = [Polestar_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Polestar_2023.pdf
# fname >>> Polestar_2023.pdf
# doc_id = [38], fname = [Polestar_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2014.pdf
# fname >>> Sainsburys_2014.pdf
# doc_id = [39], fname = [Sainsburys_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2015.pdf
# fname >>> Sainsburys_2015.pdf
# doc_id = [40], fname = [Sainsburys_2015.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2016.pdf
# fname >>> Sainsburys_2016.pdf
# doc_id = [41], fname = [Sainsburys_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2017.pdf
# fname >>> Sainsburys_2017.pdf
# doc_id = [42], fname = [Sainsburys_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2018.pdf
# fname >>> Sainsburys_2018.pdf
# doc_id = [43], fname = [Sainsburys_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2019.pdf
# fname >>> Sainsburys_2019.pdf
# doc_id = [44], fname = [Sainsburys_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2020.pdf
# fname >>> Sainsburys_2020.pdf
# doc_id = [45], fname = [Sainsburys_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2021.pdf
# fname >>> Sainsburys_2021.pdf
# doc_id = [46], fname = [Sainsburys_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2022.pdf
# fname >>> Sainsburys_2022.pdf
# doc_id = [47], fname = [Sainsburys_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Sainsburys_2023.pdf
# fname >>> Sainsburys_2023.pdf
# doc_id = [48], fname = [Sainsburys_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2014.pdf
# fname >>> Stellantis_2014.pdf
# doc_id = [49], fname = [Stellantis_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2015.pdf
# fname >>> Stellantis_2015.pdf
# doc_id = [50], fname = [Stellantis_2015.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2016.pdf
# fname >>> Stellantis_2016.pdf
# doc_id = [51], fname = [Stellantis_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2017.pdf
# fname >>> Stellantis_2017.pdf
# doc_id = [52], fname = [Stellantis_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2018.pdf
# fname >>> Stellantis_2018.pdf
# doc_id = [53], fname = [Stellantis_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2019.pdf
# fname >>> Stellantis_2019.pdf
# doc_id = [54], fname = [Stellantis_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2020.pdf
# fname >>> Stellantis_2020.pdf
# doc_id = [55], fname = [Stellantis_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2021.pdf
# fname >>> Stellantis_2021.pdf
# doc_id = [56], fname = [Stellantis_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2022.pdf
# fname >>> Stellantis_2022.pdf
# doc_id = [57], fname = [Stellantis_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Stellantis_2023.pdf
# fname >>> Stellantis_2023.pdf
# doc_id = [58], fname = [Stellantis_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2014.pdf
# fname >>> Tesco_2014.pdf
# doc_id = [59], fname = [Tesco_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2015.pdf
# fname >>> Tesco_2015.pdf
# doc_id = [60], fname = [Tesco_2015.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2016.pdf
# fname >>> Tesco_2016.pdf
# doc_id = [61], fname = [Tesco_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2017.pdf
# fname >>> Tesco_2017.pdf
# doc_id = [62], fname = [Tesco_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2018.pdf
# fname >>> Tesco_2018.pdf
# doc_id = [63], fname = [Tesco_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2019.pdf
# fname >>> Tesco_2019.pdf
# doc_id = [64], fname = [Tesco_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2020.pdf
# fname >>> Tesco_2020.pdf
# doc_id = [65], fname = [Tesco_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2021.pdf
# fname >>> Tesco_2021.pdf
# doc_id = [66], fname = [Tesco_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2022.pdf
# fname >>> Tesco_2022.pdf
# doc_id = [67], fname = [Tesco_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesco_2023.pdf
# fname >>> Tesco_2023.pdf
# doc_id = [68], fname = [Tesco_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesla_2018.pdf
# fname >>> Tesla_2018.pdf
# doc_id = [69], fname = [Tesla_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesla_2019.pdf
# fname >>> Tesla_2019.pdf
# doc_id = [70], fname = [Tesla_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesla_2020.pdf
# fname >>> Tesla_2020.pdf
# doc_id = [71], fname = [Tesla_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesla_2021.pdf
# fname >>> Tesla_2021.pdf
# doc_id = [72], fname = [Tesla_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesla_2022.pdf
# fname >>> Tesla_2022.pdf
# doc_id = [73], fname = [Tesla_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Tesla_2023.pdf
# fname >>> Tesla_2023.pdf
# doc_id = [74], fname = [Tesla_2023.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2014.pdf
# fname >>> Toyota_2014.pdf
# doc_id = [75], fname = [Toyota_2014.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2015.pdf
# fname >>> Toyota_2015.pdf
# doc_id = [76], fname = [Toyota_2015.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2016.pdf
# fname >>> Toyota_2016.pdf
# doc_id = [77], fname = [Toyota_2016.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2017.pdf
# fname >>> Toyota_2017.pdf
# doc_id = [78], fname = [Toyota_2017.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2018.pdf
# fname >>> Toyota_2018.pdf
# doc_id = [79], fname = [Toyota_2018.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2019.pdf
# fname >>> Toyota_2019.pdf
# doc_id = [80], fname = [Toyota_2019.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2020.pdf
# fname >>> Toyota_2020.pdf
# doc_id = [81], fname = [Toyota_2020.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2021.pdf
# fname >>> Toyota_2021.pdf
# doc_id = [82], fname = [Toyota_2021.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2022.pdf
# fname >>> Toyota_2022.pdf
# doc_id = [83], fname = [Toyota_2022.pdf]
#
# path + fname >>> ../Data/Input/Reports/Toyota_2023.pdf
# fname >>> Toyota_2023.pdf
# doc_id = [84], fname = [Toyota_2023.pdf]
#
# ==== End of jobs ====
# CPU times: user 41.5 s, sys: 6.06 s, total: 47.6 s
# Wall time: 49 s

# %%
df
# Out:
#       doc_id            fname  \
# 0          1    Asda_2020.pdf
# 1          1    Asda_2020.pdf
# 2          1    Asda_2020.pdf
# 3          1    Asda_2020.pdf
# 4          1    Asda_2020.pdf
# ...      ...              ...
# 1464      84  Toyota_2023.pdf
# 1465      84  Toyota_2023.pdf
# 1466      84  Toyota_2023.pdf
# 1467      84  Toyota_2023.pdf
# 1468      84  Toyota_2023.pdf
#
#                                                sentence
# 0     Our action on sustainability supports the broa...
# 1     In particular, our efforts are contributing to...
# 2     For example, our work to tackle food poverty i...
# 3     Our CCFB strategy covers every aspect of our b...
# 4     It also covers International Procurement and L...
# ...                                                 ...
# 1464  Environmental Data [O] Remanufactured and Used...
# 1465  306-2 Management of significant waste-related ...
# 1466  407-1 Operations and suppliers in which the ri...
# 1467  416-1 Assessment of the health and safety impa...
# 1468  Published: February 2024 Next scheduled report...
#
# [168277 rows x 3 columns]

# %% [markdown]
# ### Export Data to CSV File

# %%
df.to_csv(fname_out, index=False)

# %% [markdown]
# # End of file
