# %% [markdown]
# ## Objective One

# %% [markdown]
# This notebook has the following purposes:
# - Clean the raw news stories downloaded from Eikon
# - Run the sentiment analysis
# - Aggregate the data to determine insights

# %%
# Import libraries

import pandas as pd
import numpy as np
import os
import string
import torch
from transformers import pipeline
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords
import re

# Load Vader
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Initialize VADER sentiment intensity analyzer
analyzer = SentimentIntensityAnalyzer()

# Load FinBERT tokenizer and model
from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# Initialize sentiment analysis pipeline
nlp = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)



import warnings
warnings.filterwarnings('ignore')
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
file_path = '../Data/Input/Eikon/refinitiv_stories_raw.csv'
fname_out = '../Data/Output/news_df.csv'

# Read the CSV file into a DataFrame
news_df = pd.read_csv(file_path)

# Remove columns from the 8th column onwards
news_df = news_df.iloc[:, :5]  # Keep only the first 7 columns (0-indexed)

news_df
# Out:
#                                                   story  \
# 0     <div class="storyContent" lang="en"><style typ...
# 1     <div class="storyContent" lang="en"><style typ...
# 2     <div class="storyContent" lang="en"><style typ...
# 3     <div class="storyContent" lang="en"><style typ...
# 4     <div class="storyContent" lang="en"><style typ...
# ...                                                 ...
# 5161  <div class="storyContent" lang="en"><style typ...
# 5162  <div class="storyContent" lang="en"><style typ...
# 5163  <div class="storyContent" lang="en"><style typ...
# 5164  <div class="storyContent" lang="en"><style typ...
# 5165  <div class="storyContent" lang="en"><style typ...
#
#                                   date  \
# 0     2024-07-29 18:45:56.488000+00:00
# 1     2024-07-29 14:01:47.535000+00:00
# 2     2024-07-29 13:40:20.688000+00:00
# 3     2024-07-29 13:17:18.603000+00:00
# 4     2024-07-29 12:45:00.106000+00:00
# ...                                ...
# 5161  2024-05-15 20:11:27.466000+00:00
# 5162  2024-05-14 19:32:32.800000+00:00
# 5163  2024-05-14 15:09:52.109000+00:00
# 5164  2024-05-20 22:33:04.975000+00:00
# 5165  2024-05-03 19:48:58.950000+00:00
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 5161  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 5162  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 5163  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 5164  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 5165  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 5161      governance
# 5162      governance
# 5163      governance
# 5164  sustainability
# 5165  sustainability
#
# [5166 rows x 5 columns]

# %%
# Convert multiple columns to string type
columns_to_convert = ['story', 'storyId', 'company', 'ticker']
news_df[columns_to_convert] = news_df[columns_to_convert].astype(str)

# %%
# Convert the 'date' column to datetime, handling possible timezone info and various formats
# Convert the 'date' column to datetime format while considering the timezone info
news_df['date'] = pd.to_datetime(news_df['date'], errors='coerce')

# Format the datetime to 'YYYY-MM-DD HH:MM'
news_df['date'] = news_df['date'].dt.strftime('%Y-%m-%d')

news_df
# Out:
#                                                   story        date  \
# 0     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 1     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 2     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 3     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 4     <div class="storyContent" lang="en"><style typ...  2024-07-29
# ...                                                 ...         ...
# 5161  <div class="storyContent" lang="en"><style typ...  2024-05-15
# 5162  <div class="storyContent" lang="en"><style typ...  2024-05-14
# 5163  <div class="storyContent" lang="en"><style typ...  2024-05-14
# 5164  <div class="storyContent" lang="en"><style typ...  2024-05-20
# 5165  <div class="storyContent" lang="en"><style typ...  2024-05-03
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 5161  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 5162  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 5163  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 5164  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 5165  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 5161      governance
# 5162      governance
# 5163      governance
# 5164  sustainability
# 5165  sustainability
#
# [5166 rows x 5 columns]

# %%
# After inspecting the dataset, there are a few rows with compromised data. 
# Remove rows of dataset where date column doesn't have timestamp.

# Define a regular expression pattern to detect timestamps (format: YYYY-MM-DD HH:MM:SS)
timestamp_pattern = r'\d{4}-\d{2}-\d{2}'

# Filter the rows that contain timestamps in the 'date' column
news_df = news_df[news_df['date'].apply(lambda x: bool(re.match(timestamp_pattern, str(x))))]

# Reset the index of the filtered DataFrame
news_df = news_df.reset_index(drop=True)

news_df
# Out:
#                                                   story        date  \
# 0     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 1     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 2     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 3     <div class="storyContent" lang="en"><style typ...  2024-07-29
# 4     <div class="storyContent" lang="en"><style typ...  2024-07-29
# ...                                                 ...         ...
# 1078  <div class="storyContent" lang="en"><style typ...  2024-05-15
# 1079  <div class="storyContent" lang="en"><style typ...  2024-05-14
# 1080  <div class="storyContent" lang="en"><style typ...  2024-05-14
# 1081  <div class="storyContent" lang="en"><style typ...  2024-05-20
# 1082  <div class="storyContent" lang="en"><style typ...  2024-05-03
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 1078  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 1079  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1080  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1081  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 1082  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 1078      governance
# 1079      governance
# 1080      governance
# 1081  sustainability
# 1082  sustainability
#
# [1083 rows x 5 columns]

# %%
# Functions to remove text within <> and {}:

def remove_text_within_angle_brackets(text):
    if pd.notnull(text):  # Check if the text is not null
        return re.sub(r'<.*?>', '', text)
    return text  # Return the text as is if it's null

# Apply the function to the 'story' column
news_df['story'] = news_df['story'].apply(remove_text_within_angle_brackets)


def remove_text_within_curly_brackets(text):
    if pd.notnull(text):  # Check if the text is not null
        return re.sub(r'{.*?}', '', text)
    return text  # Return the text as is if it's null

# Apply the function to the 'story' column
news_df['story'] = news_df['story'].apply(remove_text_within_curly_brackets)

# Reset the index of the filtered DataFrame
news_df = news_df.reset_index(drop=True)

news_df
# Out:
#                                                   story        date  \
# 0     .storyContent * LOS ANGELES, CA / ACCESSWIRE /...  2024-07-29
# 1     .storyContent * NEW YORK CITY, NY / ACCESSWIRE...  2024-07-29
# 2     .storyContent * FORD ALERT: Bragar Eagel &amp;...  2024-07-29
# 3     .storyContent * FIRST ATLANTIC NICKEL CORP ("F...  2024-07-29
# 4     .storyContent * PALM BEACH, Fla., July  29, 20...  2024-07-29
# ...                                                 ...         ...
# 1078  .storyContent * Tesco, the UK's largest superm...  2024-05-15
# 1079  .storyContent * Tesco has been accused of givi...  2024-05-14
# 1080  .storyContent * Tesco boss Ken Murphy has seen...  2024-05-14
# 1081  .storyContent * Tesco has apologised after a B...  2024-05-20
# 1082  .storyContent * Tesco Ireland, the Republic of...  2024-05-03
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 1078  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 1079  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1080  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1081  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 1082  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 1078      governance
# 1079      governance
# 1080      governance
# 1081  sustainability
# 1082  sustainability
#
# [1083 rows x 5 columns]

# %%
# Remove '.storyContent * ' substring from the 'story' column
news_df['story'] = news_df['story'].str.replace('.storyContent * ', '', regex=False)

# Reset the index of the filtered DataFrame
news_df = news_df.reset_index(drop=True)

news_df
# Out:
#                                                   story        date  \
# 0     LOS ANGELES, CA / ACCESSWIRE / July 29, 2024 /...  2024-07-29
# 1     NEW YORK CITY, NY / ACCESSWIRE / July 29, 2024...  2024-07-29
# 2     FORD ALERT: Bragar Eagel &amp; Squire, P.C. is...  2024-07-29
# 3     FIRST ATLANTIC NICKEL CORP ("FAN-V")\nALASKA E...  2024-07-29
# 4     PALM BEACH, Fla., July  29, 2024  (GLOBE NEWSW...  2024-07-29
# ...                                                 ...         ...
# 1078  Tesco, the UK's largest supermarket chain, has...  2024-05-15
# 1079  Tesco has been accused of giving struggling wo...  2024-05-14
# 1080  Tesco boss Ken Murphy has seen his pay deal mo...  2024-05-14
# 1081  Tesco has apologised after a Black publisher s...  2024-05-20
# 1082  Tesco Ireland, the Republic of Ireland- based ...  2024-05-03
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 1078  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 1079  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1080  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1081  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 1082  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 1078      governance
# 1079      governance
# 1080      governance
# 1081  sustainability
# 1082  sustainability
#
# [1083 rows x 5 columns]

# %%
news_df
# Out:
#                                                   story        date  \
# 0     LOS ANGELES, CA / ACCESSWIRE / July 29, 2024 /...  2024-07-29
# 1     NEW YORK CITY, NY / ACCESSWIRE / July 29, 2024...  2024-07-29
# 2     FORD ALERT: Bragar Eagel &amp; Squire, P.C. is...  2024-07-29
# 3     FIRST ATLANTIC NICKEL CORP ("FAN-V")\nALASKA E...  2024-07-29
# 4     PALM BEACH, Fla., July  29, 2024  (GLOBE NEWSW...  2024-07-29
# ...                                                 ...         ...
# 1078  Tesco, the UK's largest supermarket chain, has...  2024-05-15
# 1079  Tesco has been accused of giving struggling wo...  2024-05-14
# 1080  Tesco boss Ken Murphy has seen his pay deal mo...  2024-05-14
# 1081  Tesco has apologised after a Black publisher s...  2024-05-20
# 1082  Tesco Ireland, the Republic of Ireland- based ...  2024-05-03
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 1078  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 1079  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1080  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1081  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 1082  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 1078      governance
# 1079      governance
# 1080      governance
# 1081  sustainability
# 1082  sustainability
#
# [1083 rows x 5 columns]

# %%
# Remove rows with empty cells

news_df = news_df.dropna(how='any')

# Reset the index of the filtered DataFrame
news_df = news_df.reset_index(drop=True)

news_df
# Out:
#                                                   story        date  \
# 0     LOS ANGELES, CA / ACCESSWIRE / July 29, 2024 /...  2024-07-29
# 1     NEW YORK CITY, NY / ACCESSWIRE / July 29, 2024...  2024-07-29
# 2     FORD ALERT: Bragar Eagel &amp; Squire, P.C. is...  2024-07-29
# 3     FIRST ATLANTIC NICKEL CORP ("FAN-V")\nALASKA E...  2024-07-29
# 4     PALM BEACH, Fla., July  29, 2024  (GLOBE NEWSW...  2024-07-29
# ...                                                 ...         ...
# 1078  Tesco, the UK's largest supermarket chain, has...  2024-05-15
# 1079  Tesco has been accused of giving struggling wo...  2024-05-14
# 1080  Tesco boss Ken Murphy has seen his pay deal mo...  2024-05-14
# 1081  Tesco has apologised after a Black publisher s...  2024-05-20
# 1082  Tesco Ireland, the Republic of Ireland- based ...  2024-05-03
#
#                                                 storyId company  \
# 0     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1     urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3     urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4     urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ...                                                 ...     ...
# 1078  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 1079  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1080  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 1081  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 1082  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#               ticker
# 0                esg
# 1                esg
# 2                esg
# 3                esg
# 4                esg
# ...              ...
# 1078      governance
# 1079      governance
# 1080      governance
# 1081  sustainability
# 1082  sustainability
#
# [1083 rows x 5 columns]

# %%
# Function to count the number of words in a string
def word_count(text):
    if pd.notnull(text):  # Check if the text is not null
        return len(text.split())
    return 0  # Return 0 if the text is null

# Filter out rows where the word count in 'story' column is less than 15
news_df = news_df[news_df['story'].apply(word_count) >= 15]

# Filter out rows where any column is empty or contains only whitespace
news_df = news_df[(news_df != '') & (news_df != ' ')].dropna()

# Reset the index of the filtered DataFrame
news_df = news_df.reset_index(drop=True)

news_df
# Out:
#                                                  story        date  \
# 0    LOS ANGELES, CA / ACCESSWIRE / July 29, 2024 /...  2024-07-29
# 1    NEW YORK CITY, NY / ACCESSWIRE / July 29, 2024...  2024-07-29
# 2    FORD ALERT: Bragar Eagel &amp; Squire, P.C. is...  2024-07-29
# 3    FIRST ATLANTIC NICKEL CORP ("FAN-V")\nALASKA E...  2024-07-29
# 4    PALM BEACH, Fla., July  29, 2024  (GLOBE NEWSW...  2024-07-29
# ..                                                 ...         ...
# 985  Tesco, the UK's largest supermarket chain, has...  2024-05-15
# 986  Tesco has been accused of giving struggling wo...  2024-05-14
# 987  Tesco boss Ken Murphy has seen his pay deal mo...  2024-05-14
# 988  Tesco has apologised after a Black publisher s...  2024-05-20
# 989  Tesco Ireland, the Republic of Ireland- based ...  2024-05-03
#
#                                                storyId company          ticker
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford             esg
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford             esg
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford             esg
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford             esg
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford             esg
# ..                                                 ...     ...             ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco      governance
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco      governance
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco      governance
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco  sustainability
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco  sustainability
#
# [990 rows x 5 columns]

# %%
# Strip whitespace from all columns and replace empty strings with NaN
news_df = news_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
news_df.replace('', pd.NA, inplace=True)

# Drop rows with any NaN values
news_df.dropna(inplace=True)

# Reset the index of the filtered DataFrame
news_df = news_df.reset_index(drop=True)

news_df
# Out:
#                                                  story        date  \
# 0    LOS ANGELES, CA / ACCESSWIRE / July 29, 2024 /...  2024-07-29
# 1    NEW YORK CITY, NY / ACCESSWIRE / July 29, 2024...  2024-07-29
# 2    FORD ALERT: Bragar Eagel &amp; Squire, P.C. is...  2024-07-29
# 3    FIRST ATLANTIC NICKEL CORP ("FAN-V")\nALASKA E...  2024-07-29
# 4    PALM BEACH, Fla., July  29, 2024  (GLOBE NEWSW...  2024-07-29
# ..                                                 ...         ...
# 985  Tesco, the UK's largest supermarket chain, has...  2024-05-15
# 986  Tesco has been accused of giving struggling wo...  2024-05-14
# 987  Tesco boss Ken Murphy has seen his pay deal mo...  2024-05-14
# 988  Tesco has apologised after a Black publisher s...  2024-05-20
# 989  Tesco Ireland, the Republic of Ireland- based ...  2024-05-03
#
#                                                storyId company          ticker
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford             esg
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford             esg
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford             esg
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford             esg
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford             esg
# ..                                                 ...     ...             ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco      governance
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco      governance
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco      governance
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco  sustainability
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco  sustainability
#
# [990 rows x 5 columns]

# %%
news_df.to_csv(fname_out, index=False)

# %%
# Aggregate the 'company' column and calculate the total number of rows for each unique value
company_counts = news_df.groupby('company').size().reset_index(name='total_rows')
# Sort the results
company_counts = company_counts.sort_values(by='total_rows', ascending=False)


# Display the aggregated DataFrame
print(company_counts)
# Out:
#            company  total_rows
# 9           Toyota         324
# 1             Ford         261
# 8            Tesla         198
# 7            Tesco          58
# 2  Marks & Spencer          56
# 3            Ocado          38
# 6       Stellantis          31
# 5       Sainsburys           9
# 4         Polestar           8
# 0             Asda           7

# %%
# Group by both 'company' and 'ticker' columns and calculate the number of rows for each group
aggregated_counts = news_df.groupby(['company', 'ticker']).size().reset_index(name='total_rows')

# aggregated_counts = aggregated_counts.sort_values(by='total_rows', ascending=False)

# Display the aggregated DataFrame
print(aggregated_counts)
# Out:
#             company          ticker  total_rows
# 0              Asda     environment           1
# 1              Asda             esg           4
# 2              Asda  sustainability           2
# 3              Ford     environment           3
# 4              Ford             esg          99
# 5              Ford      governance          99
# 6              Ford          social          57
# 7              Ford  sustainability           3
# 8   Marks & Spencer     environment           4
# 9   Marks & Spencer             esg           3
# 10  Marks & Spencer          social          45
# 11  Marks & Spencer  sustainability           4
# 12            Ocado             esg           2
# 13            Ocado          social          36
# 14         Polestar     environment           4
# 15         Polestar             esg           1
# 16         Polestar  sustainability           3
# 17       Sainsburys     environment           3
# 18       Sainsburys             esg           4
# 19       Sainsburys  sustainability           2
# 20       Stellantis     environment           4
# 21       Stellantis             esg          25
# 22       Stellantis  sustainability           2
# 23            Tesco     environment           3
# 24            Tesco             esg           9
# 25            Tesco      governance           5
# 26            Tesco          social          39
# 27            Tesco  sustainability           2
# 28            Tesla     environment          34
# 29            Tesla             esg          62
# 30            Tesla      governance          45
# 31            Tesla          social          44
# 32            Tesla  sustainability          13
# 33           Toyota     environment          21
# 34           Toyota             esg          96
# 35           Toyota      governance          99
# 36           Toyota          social          78
# 37           Toyota  sustainability          30

# %%
# Removing punctuation to optimise the polarity

# Define function to remove punctuation
def remove_punctuation(text):
    if pd.isna(text):
        return text
    return text.translate(str.maketrans('', '', string.punctuation))

# Apply the function to the 'story' column
news_df['story'] = news_df['story'].apply(remove_punctuation)

# Display the DataFrame
print(news_df[['story']])
# Out:
#                                                  story
# 0    LOS ANGELES CA  ACCESSWIRE  July 29 2024  The ...
# 1    NEW YORK CITY NY  ACCESSWIRE  July 29 2024  Br...
# 2    FORD ALERT Bragar Eagel amp Squire PC is Inves...
# 3    FIRST ATLANTIC NICKEL CORP FANV\nALASKA ENERGY...
# 4    PALM BEACH Fla July  29 2024  GLOBE NEWSWIRE  ...
# ..                                                 ...
# 985  Tesco the UKs largest supermarket chain has sp...
# 986  Tesco has been accused of giving struggling wo...
# 987  Tesco boss Ken Murphy has seen his pay deal mo...
# 988  Tesco has apologised after a Black publisher s...
# 989  Tesco Ireland the Republic of Ireland based su...
#
# [990 rows x 1 columns]

# %%
# Convert the 'story' column to lowercase to optimise polarity
news_df['story'] = news_df['story'].str.lower()

# Display the updated DataFrame
print(news_df[['story']])
# Out:
#                                                  story
# 0    los angeles ca  accesswire  july 29 2024  the ...
# 1    new york city ny  accesswire  july 29 2024  br...
# 2    ford alert bragar eagel amp squire pc is inves...
# 3    first atlantic nickel corp fanv\nalaska energy...
# 4    palm beach fla july  29 2024  globe newswire  ...
# ..                                                 ...
# 985  tesco the uks largest supermarket chain has sp...
# 986  tesco has been accused of giving struggling wo...
# 987  tesco boss ken murphy has seen his pay deal mo...
# 988  tesco has apologised after a black publisher s...
# 989  tesco ireland the republic of ireland based su...
#
# [990 rows x 1 columns]

# %%
news_df
# Out:
#                                                  story        date  \
# 0    los angeles ca  accesswire  july 29 2024  the ...  2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br...  2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves...  2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy...  2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ...  2024-07-29
# ..                                                 ...         ...
# 985  tesco the uks largest supermarket chain has sp...  2024-05-15
# 986  tesco has been accused of giving struggling wo...  2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo...  2024-05-14
# 988  tesco has apologised after a black publisher s...  2024-05-20
# 989  tesco ireland the republic of ireland based su...  2024-05-03
#
#                                                storyId company          ticker
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford             esg
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford             esg
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford             esg
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford             esg
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford             esg
# ..                                                 ...     ...             ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco      governance
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco      governance
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco      governance
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco  sustainability
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco  sustainability
#
# [990 rows x 5 columns]

# %%
# Function to calculate normalized sentiment score between 0 and 1
def calculate_normalized_score(text):
    sentiment = analyzer.polarity_scores(text)
    # VADER's compound score ranges from -1 to 1, normalize to 0 to 1
    normalized_score = (sentiment['compound'] + 1) / 2
    return normalized_score

# Apply the function to the DataFrame column
news_df['sentiment_score'] = news_df['story'].apply(calculate_normalized_score)

news_df
# Out:
#                                                  story        date  \
# 0    los angeles ca  accesswire  july 29 2024  the ...  2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br...  2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves...  2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy...  2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ...  2024-07-29
# ..                                                 ...         ...
# 985  tesco the uks largest supermarket chain has sp...  2024-05-15
# 986  tesco has been accused of giving struggling wo...  2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo...  2024-05-14
# 988  tesco has apologised after a black publisher s...  2024-05-20
# 989  tesco ireland the republic of ireland based su...  2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score
# 0               esg          0.76335
# 1               esg          0.16265
# 2               esg          0.95170
# 3               esg          0.99970
# 4               esg          0.99965
# ..              ...              ...
# 985      governance          0.97300
# 986      governance          0.99495
# 987      governance          0.99360
# 988  sustainability          0.02185
# 989  sustainability          0.99715
#
# [990 rows x 6 columns]

# %%
# Sentiment analysis using FinBERT
# Because the limit of FinBERT is 512 tokens, splitting the text 
# into chunks of 512 tokens or less before processing is required.

def analyse_sentiment_with_chunking(text, max_length=512):
    # Tokenize and split the text into chunks of max_length tokens
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=max_length, padding='max_length')

    # Split the inputs into smaller chunks if they exceed the max_length
    input_ids = inputs['input_ids'].squeeze(0)
    attention_mask = inputs['attention_mask'].squeeze(0)

    chunks = []
    for i in range(0, len(input_ids), max_length):
        chunk_input_ids = input_ids[i:i + max_length].unsqueeze(0)
        chunk_attention_mask = attention_mask[i:i + max_length].unsqueeze(0)
        chunks.append((chunk_input_ids, chunk_attention_mask))
    
    sentiments = []
    for chunk_input_ids, chunk_attention_mask in chunks:
        with torch.no_grad():
            outputs = model(chunk_input_ids, attention_mask=chunk_attention_mask)
        logits = outputs.logits
        sentiment = torch.argmax(logits, dim=1).item()
        sentiments.append(sentiment)

    # Return the most frequent sentiment across all chunks
    return max(set(sentiments), key=sentiments.count)

# Apply the function to the 'story' column
news_df['finbert_score'] = news_df['story'].apply(analyse_sentiment_with_chunking)

news_df
# Out:
#                                                  story        date  \
# 0    los angeles ca  accesswire  july 29 2024  the ...  2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br...  2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves...  2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy...  2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ...  2024-07-29
# ..                                                 ...         ...
# 985  tesco the uks largest supermarket chain has sp...  2024-05-15
# 986  tesco has been accused of giving struggling wo...  2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo...  2024-05-14
# 988  tesco has apologised after a black publisher s...  2024-05-20
# 989  tesco ireland the republic of ireland based su...  2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score  finbert_score
# 0               esg          0.76335              1
# 1               esg          0.16265              2
# 2               esg          0.95170              2
# 3               esg          0.99970              2
# 4               esg          0.99965              2
# ..              ...              ...            ...
# 985      governance          0.97300              1
# 986      governance          0.99495              1
# 987      governance          0.99360              0
# 988  sustainability          0.02185              2
# 989  sustainability          0.99715              2
#
# [990 rows x 7 columns]

# %%
# Define the mapping from sentiment scores to labels
sentiment_mapping = {
    0: 'negative',
    1: 'neutral',
    2: 'positive'
}

# Apply the mapping to create the new 'sentiment' column
news_df['sentiment'] = news_df['finbert_score'].map(sentiment_mapping)

news_df
# Out:
#                                                  story        date  \
# 0    los angeles ca  accesswire  july 29 2024  the ...  2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br...  2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves...  2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy...  2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ...  2024-07-29
# ..                                                 ...         ...
# 985  tesco the uks largest supermarket chain has sp...  2024-05-15
# 986  tesco has been accused of giving struggling wo...  2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo...  2024-05-14
# 988  tesco has apologised after a black publisher s...  2024-05-20
# 989  tesco ireland the republic of ireland based su...  2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score  finbert_score sentiment
# 0               esg          0.76335              1   neutral
# 1               esg          0.16265              2  positive
# 2               esg          0.95170              2  positive
# 3               esg          0.99970              2  positive
# 4               esg          0.99965              2  positive
# ..              ...              ...            ...       ...
# 985      governance          0.97300              1   neutral
# 986      governance          0.99495              1   neutral
# 987      governance          0.99360              0  negative
# 988  sustainability          0.02185              2  positive
# 989  sustainability          0.99715              2  positive
#
# [990 rows x 8 columns]

# %%
# Define the weights sentiment labels
sentiment_mapping = {
    'negative': -1,
    'neutral': 0,
    'positive': 1
}

# Apply the mapping to create the new 'sentiment' column
news_df['weight'] = news_df['sentiment'].map(sentiment_mapping)

news_df
# Out:
#                                                  story        date  \
# 0    los angeles ca  accesswire  july 29 2024  the ...  2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br...  2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves...  2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy...  2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ...  2024-07-29
# ..                                                 ...         ...
# 985  tesco the uks largest supermarket chain has sp...  2024-05-15
# 986  tesco has been accused of giving struggling wo...  2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo...  2024-05-14
# 988  tesco has apologised after a black publisher s...  2024-05-20
# 989  tesco ireland the republic of ireland based su...  2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score  finbert_score sentiment  weight
# 0               esg          0.76335              1   neutral       0
# 1               esg          0.16265              2  positive       1
# 2               esg          0.95170              2  positive       1
# 3               esg          0.99970              2  positive       1
# 4               esg          0.99965              2  positive       1
# ..              ...              ...            ...       ...     ...
# 985      governance          0.97300              1   neutral       0
# 986      governance          0.99495              1   neutral       0
# 987      governance          0.99360              0  negative      -1
# 988  sustainability          0.02185              2  positive       1
# 989  sustainability          0.99715              2  positive       1
#
# [990 rows x 9 columns]

# %%
# Define the composite score as the result of weight x sentiment_score

news_df['composite_score'] = news_df['weight'] * news_df['sentiment_score']
news_df
# Out:
#                                                  story        date  \
# 0    los angeles ca  accesswire  july 29 2024  the ...  2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br...  2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves...  2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy...  2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ...  2024-07-29
# ..                                                 ...         ...
# 985  tesco the uks largest supermarket chain has sp...  2024-05-15
# 986  tesco has been accused of giving struggling wo...  2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo...  2024-05-14
# 988  tesco has apologised after a black publisher s...  2024-05-20
# 989  tesco ireland the republic of ireland based su...  2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score  finbert_score sentiment  weight  \
# 0               esg          0.76335              1   neutral       0
# 1               esg          0.16265              2  positive       1
# 2               esg          0.95170              2  positive       1
# 3               esg          0.99970              2  positive       1
# 4               esg          0.99965              2  positive       1
# ..              ...              ...            ...       ...     ...
# 985      governance          0.97300              1   neutral       0
# 986      governance          0.99495              1   neutral       0
# 987      governance          0.99360              0  negative      -1
# 988  sustainability          0.02185              2  positive       1
# 989  sustainability          0.99715              2  positive       1
#
#      composite_score
# 0            0.00000
# 1            0.16265
# 2            0.95170
# 3            0.99970
# 4            0.99965
# ..               ...
# 985          0.00000
# 986          0.00000
# 987         -0.99360
# 988          0.02185
# 989          0.99715
#
# [990 rows x 10 columns]

# %%
# Group by company and calculate the average composite_score across the entire period
average_scores = news_df.groupby('company')['composite_score'].mean().reset_index()
average_scores
# Out:
#            company  composite_score
# 0             Asda        -0.004857
# 1             Ford         0.356515
# 2  Marks & Spencer         0.794787
# 3            Ocado         0.206816
# 4         Polestar         0.691638
# 5       Sainsburys         0.761650
# 6       Stellantis         0.323995
# 7            Tesco         0.600731
# 8            Tesla         0.413659
# 9           Toyota         0.445728

# %%
# Convert 'date' column to datetime
news_df['date'] = pd.to_datetime(news_df['date'])

# Extract month and year from 'date'
news_df['month'] = news_df['date'].dt.to_period('M')

news_df
# Out:
#                                                  story       date  \
# 0    los angeles ca  accesswire  july 29 2024  the ... 2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br... 2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves... 2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy... 2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ... 2024-07-29
# ..                                                 ...        ...
# 985  tesco the uks largest supermarket chain has sp... 2024-05-15
# 986  tesco has been accused of giving struggling wo... 2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo... 2024-05-14
# 988  tesco has apologised after a black publisher s... 2024-05-20
# 989  tesco ireland the republic of ireland based su... 2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score  finbert_score sentiment  weight  \
# 0               esg          0.76335              1   neutral       0
# 1               esg          0.16265              2  positive       1
# 2               esg          0.95170              2  positive       1
# 3               esg          0.99970              2  positive       1
# 4               esg          0.99965              2  positive       1
# ..              ...              ...            ...       ...     ...
# 985      governance          0.97300              1   neutral       0
# 986      governance          0.99495              1   neutral       0
# 987      governance          0.99360              0  negative      -1
# 988  sustainability          0.02185              2  positive       1
# 989  sustainability          0.99715              2  positive       1
#
#      composite_score    month
# 0            0.00000  2024-07
# 1            0.16265  2024-07
# 2            0.95170  2024-07
# 3            0.99970  2024-07
# 4            0.99965  2024-07
# ..               ...      ...
# 985          0.00000  2024-05
# 986          0.00000  2024-05
# 987         -0.99360  2024-05
# 988          0.02185  2024-05
# 989          0.99715  2024-05
#
# [990 rows x 11 columns]

# %%
# Group by company and month, then calculate the average composite_score
monthly_average_scores = news_df.groupby(['company', 'month'])['composite_score'].mean().reset_index()
monthly_average_scores
# Out:
#             company    month  composite_score
# 0              Asda  2024-06         0.000000
# 1              Asda  2024-07        -0.005667
# 2              Ford  2024-05        -0.998100
# 3              Ford  2024-06         0.420789
# 4              Ford  2024-07         0.360452
# 5   Marks & Spencer  2024-05         0.493237
# 6   Marks & Spencer  2024-06         0.759700
# 7   Marks & Spencer  2024-07         0.857465
# 8             Ocado  2024-05         0.996800
# 9             Ocado  2024-07         0.185465
# 10         Polestar  2024-06         0.691638
# 11       Sainsburys  2024-06         0.958450
# 12       Sainsburys  2024-07         0.663250
# 13       Stellantis  2024-05         0.542975
# 14       Stellantis  2024-06         0.476891
# 15       Stellantis  2024-07         0.037854
# 16            Tesco  2024-05         0.001237
# 17            Tesco  2024-06         0.306595
# 18            Tesco  2024-07         0.882267
# 19            Tesla  2024-05         0.244527
# 20            Tesla  2024-06         0.502382
# 21            Tesla  2024-07         0.383009
# 22           Toyota  2024-05         0.821712
# 23           Toyota  2024-06         0.570125
# 24           Toyota  2024-07         0.405789

# %%
# Convert 'date' column to datetime
news_df['date'] = pd.to_datetime(news_df['date'])

# Extract week of the year and year from 'date'
news_df['week_of_year'] = news_df['date'].dt.isocalendar().week
news_df['year'] = news_df['date'].dt.year

news_df
# Out:
#                                                  story       date  \
# 0    los angeles ca  accesswire  july 29 2024  the ... 2024-07-29
# 1    new york city ny  accesswire  july 29 2024  br... 2024-07-29
# 2    ford alert bragar eagel amp squire pc is inves... 2024-07-29
# 3    first atlantic nickel corp fanv\nalaska energy... 2024-07-29
# 4    palm beach fla july  29 2024  globe newswire  ... 2024-07-29
# ..                                                 ...        ...
# 985  tesco the uks largest supermarket chain has sp... 2024-05-15
# 986  tesco has been accused of giving struggling wo... 2024-05-14
# 987  tesco boss ken murphy has seen his pay deal mo... 2024-05-14
# 988  tesco has apologised after a black publisher s... 2024-05-20
# 989  tesco ireland the republic of ireland based su... 2024-05-03
#
#                                                storyId company  \
# 0    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 1    urn:newsml:newswire.refinitiv.com:20240729:nAC...    Ford
# 2    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 3    urn:newsml:newsroom.refinitiv.com:20240729:nVM...    Ford
# 4    urn:newsml:newswire.refinitiv.com:20240729:nGN...    Ford
# ..                                                 ...     ...
# 985  urn:newsml:newswire.refinitiv.com:20240515:nNR...   Tesco
# 986  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 987  urn:newsml:newswire.refinitiv.com:20240514:nNR...   Tesco
# 988  urn:newsml:newswire.refinitiv.com:20240520:nNR...   Tesco
# 989  urn:newsml:newswire.refinitiv.com:20240503:nNR...   Tesco
#
#              ticker  sentiment_score  finbert_score sentiment  weight  \
# 0               esg          0.76335              1   neutral       0
# 1               esg          0.16265              2  positive       1
# 2               esg          0.95170              2  positive       1
# 3               esg          0.99970              2  positive       1
# 4               esg          0.99965              2  positive       1
# ..              ...              ...            ...       ...     ...
# 985      governance          0.97300              1   neutral       0
# 986      governance          0.99495              1   neutral       0
# 987      governance          0.99360              0  negative      -1
# 988  sustainability          0.02185              2  positive       1
# 989  sustainability          0.99715              2  positive       1
#
#      composite_score    month  week_of_year  year
# 0            0.00000  2024-07            31  2024
# 1            0.16265  2024-07            31  2024
# 2            0.95170  2024-07            31  2024
# 3            0.99970  2024-07            31  2024
# 4            0.99965  2024-07            31  2024
# ..               ...      ...           ...   ...
# 985          0.00000  2024-05            20  2024
# 986          0.00000  2024-05            20  2024
# 987         -0.99360  2024-05            20  2024
# 988          0.02185  2024-05            21  2024
# 989          0.99715  2024-05            18  2024
#
# [990 rows x 13 columns]

# %%
# Set display options to show more rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
# Group by company and week of the year, then calculate the average composite_score
weekly_average_composite_scores = news_df.groupby(['company', 'year', 'week_of_year'])['composite_score'].mean().reset_index()


weekly_average_composite_scores.to_csv('../Data/Output/obj1_weekly_average_composite_scores.csv', index=False)

weekly_average_composite_scores
# Out:
#             company  year  week_of_year  composite_score
# 0              Asda  2024            23         0.000000
# 1              Asda  2024            28        -0.980000
# 2              Asda  2024            30         0.481500
# 3              Ford  2024            18        -0.998100
# 4              Ford  2024            25         0.368219
# 5              Ford  2024            26         0.441817
# 6              Ford  2024            27         0.492020
# 7              Ford  2024            28         0.421264
# 8              Ford  2024            29         0.464823
# 9              Ford  2024            30         0.226375
# 10             Ford  2024            31         0.555800
# 11  Marks & Spencer  2024            21        -0.999600
# 12  Marks & Spencer  2024            22         0.743138
# 13  Marks & Spencer  2024            23         0.562288
# 14  Marks & Spencer  2024            24         0.331400
# 15  Marks & Spencer  2024            25         0.976717
# 16  Marks & Spencer  2024            26         0.978579
# 17  Marks & Spencer  2024            27         0.906824
# 18  Marks & Spencer  2024            28         0.839500
# 19  Marks & Spencer  2024            29         0.767892
# 20  Marks & Spencer  2024            30         0.693200
# 21            Ocado  2024            19         0.996800
# 22            Ocado  2024            28         0.000000
# 23            Ocado  2024            29         0.094803
# 24            Ocado  2024            30        -0.010725
# 25            Ocado  2024            31         0.452596
# 26         Polestar  2024            23         0.888425
# 27         Polestar  2024            26         0.494850
# 28       Sainsburys  2024            24         0.958450
# 29       Sainsburys  2024            27         0.596790
# 30       Sainsburys  2024            29         0.995550
# 31       Stellantis  2024            18         0.999300
# 32       Stellantis  2024            19         0.478433
# 33       Stellantis  2024            20         0.478333
# 34       Stellantis  2024            22         0.474200
# 35       Stellantis  2024            24         0.361470
# 36       Stellantis  2024            25         0.600750
# 37       Stellantis  2024            26         0.545400
# 38       Stellantis  2024            28         0.959300
# 39       Stellantis  2024            29        -0.126262
# 40       Stellantis  2024            30         0.000000
# 41       Stellantis  2024            31         0.000000
# 42            Tesco  2024            18         0.997150
# 43            Tesco  2024            19         0.000000
# 44            Tesco  2024            20        -0.331200
# 45            Tesco  2024            21         0.021850
# 46            Tesco  2024            22         0.327683
# 47            Tesco  2024            23         0.934350
# 48            Tesco  2024            24         0.050517
# 49            Tesco  2024            26         0.330008
# 50            Tesco  2024            27         0.885000
# 51            Tesco  2024            28         0.968650
# 52            Tesco  2024            29         0.991467
# 53            Tesco  2024            30         0.790573
# 54            Tesco  2024            31         0.908800
# 55            Tesla  2024            19         0.243300
# 56            Tesla  2024            20         0.079392
# 57            Tesla  2024            21         0.204830
# 58            Tesla  2024            22         0.408550
# 59            Tesla  2024            23         0.733073
# 60            Tesla  2024            24         0.396563
# 61            Tesla  2024            25         0.652770
# 62            Tesla  2024            26         0.533986
# 63            Tesla  2024            27        -0.198985
# 64            Tesla  2024            28         0.551350
# 65            Tesla  2024            29         0.663272
# 66            Tesla  2024            30         0.474873
# 67            Tesla  2024            31         0.166405
# 68           Toyota  2024            18         0.997050
# 69           Toyota  2024            20         0.330467
# 70           Toyota  2024            22         0.813021
# 71           Toyota  2024            23         0.513606
# 72           Toyota  2024            24         0.799490
# 73           Toyota  2024            25         0.067917
# 74           Toyota  2024            26         0.976100
# 75           Toyota  2024            28         0.623864
# 76           Toyota  2024            29         0.346549
# 77           Toyota  2024            30         0.411227
# 78           Toyota  2024            31         0.404959
